# %%
# !pip install -q google-generativeai
import google.generativeai as genai
API_KEY = "AIzaSyCjNt2ciHMi7nkyb71kh1ifEGBTFH2W0A8"  
genai.configure(api_key=API_KEY)
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)


model = genai.GenerativeModel("models/gemini-2.5-flash") 
print("🤖 Gemini Research Agent is ready! Type 'exit' to stop.\n")

while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Chat ended.")
        break

    response = model.generate_content(user_input)
    print("Gemini:", response.text)
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# 🤖 Gemini Research Agent is ready! Type 'exit' to stop.
#
# Gemini: Deep learning is a specialized field within **machine learning**, which itself is a subfield of **artificial intelligence (AI)**.
#
# At its core, deep learning is inspired by the structure and function of the human brain, using artificial neural networks that are "deep" – meaning they have many layers.
#
# Here's a breakdown:
#
# 1.  **Subset of Machine Learning:** While all deep learning is machine learning, not all machine learning is deep learning. Traditional machine learning often requires human engineers to hand-craft "features" (specific attributes or characteristics) from data for the algorithm to learn from. Deep learning largely automates this feature extraction process.
#
# 2.  **Artificial Neural Networks (ANNs):**
#     *   Deep learning models are built using ANNs, which are composed of interconnected "nodes" (neurons) organized in layers.
#     *   Each connection between neurons has a "weight," and each neuron has a "bias." These are the parameters that the network learns during training.
#
# 3.  **"Deep" Means Many Layers:**
#     *   A neural network typically has an **input layer**, one or more **hidden layers**, and an **output layer**.
#     *   In deep learning, the "deep" refers to having many (often dozens, hundreds, or even thousands) of **hidden layers** between the input and output layers.
#     *   Each hidden layer learns to recognize increasingly complex patterns or "features" from the raw input data. For example, in image recognition:
#         *   The first layer might detect simple edges.
#         *   The next layer might combine edges to form shapes.
#         *   Subsequent layers might combine shapes to recognize parts of objects (like an eye or a wheel).
#         *   The final layers combine these parts to identify the entire object (like a face or a car).
#
# 4.  **How it Learns (Training):**
#     *   **Data:** Deep learning models require vast amounts of data (e.g., millions of images, hours of audio, terabytes of text). This data is often "labeled" (e.g., an image of a cat is labeled "cat").
#     *   **Forward Propagation:** Input data is fed into the network, passing through each layer. At each neuron, inputs are multiplied by weights, summed, and then passed through an "activation function" before being sent to the next layer. This process continues until an output is produced.
#     *   **Loss Function:** The network's output is compared to the actual correct label (if it's training data) using a "loss function," which measures how "wrong" the prediction was.
#     *   **Backpropagation & Optimization:** The error from the loss function is then "propagated backward" through the network. An optimization algorithm (like Gradient Descent) uses this error to adjust the weights and biases of the connections in each layer, aiming to minimize the loss and make the network's predictions more accurate over time. This iterative process is called **training**.
#
# 5.  **Key Characteristics & Advantages:**
#     *   **Automatic Feature Extraction:** This is one of its biggest advantages. Unlike traditional ML, deep learning models automatically discover the relevant features from raw data, eliminating the need for manual feature engineering by humans.
#     *   **Performance with Big Data:** Deep learning models truly shine when given huge datasets, often outperforming other ML techniques in such scenarios.
#     *   **Scalability:** Can be scaled to handle incredibly complex problems and large-scale data.
#     *   **Versatility:** Applicable to various data types (images, text, audio, time series, etc.).
#
# 6.  **Requirements:**
#     *   **Massive Datasets:** Requires a lot of data to learn effectively.
#     *   **Computational Power:** Training deep learning models is computationally intensive, often requiring specialized hardware like GPUs (Graphics Processing Units) or TPUs (Tensor Processing Units).
#
# **Common Applications:**
# *   **Image Recognition:** Face detection, object recognition (self-driving cars), medical image analysis.
# *   **Natural Language Processing (NLP):** Language translation (Google Translate), chatbots, sentiment analysis, spam detection, text generation (like ChatGPT).
# *   **Speech Recognition:** Voice assistants (Siri, Alexa), transcription services.
# *   **Recommendation Systems:** Personalizing content on Netflix, Amazon, Spotify.
# *   **Generative AI:** Creating realistic images (DALL-E, Midjourney), videos, or text.
# *   **Drug Discovery:** Identifying potential drug candidates.
#
# In essence, deep learning is a powerful approach that leverages multi-layered neural networks to learn intricate patterns and representations directly from vast amounts of data, leading to state-of-the-art performance in many complex AI tasks.
# Gemini: Ah, "quality coffee" in France! While France has historically been more about the *café experience* (sitting for hours, people-watching) rather than specialty coffee as the focus, the scene has exploded in the last decade. You're in luck, but the best spots are highly concentrated in the major cities, especially Paris.
#
# Here are some of the absolute best, focusing on **specialty coffee, expert brewing, and passionate baristas**.
#
# ---
#
# ## Best Coffee Shops in Paris (The Epicenter)
#
# If you're looking for true quality, Paris is where you'll find the highest concentration.
#
# 1.  **Belleville Brûlerie / Back in Black:**
#     *   **Why it's great:** Belleville Brûlerie is one of Paris's leading specialty roasters. **Back in Black** is their flagship cafe, a large, industrial-chic space where you can get incredible espresso, a variety of filter coffees, and watch the world go by. They roast fantastic beans, and their baristas are top-notch.
#     *   **Locations:** Back in Black (11e), plus other Belleville cafes (like their original small spot in Belleville, and others).
#     *   **Must-try:** Any of their single-origin filter coffees.
#
# 2.  **Telescope Café:**
#     *   **Why it's great:** One of the pioneers of specialty coffee in Paris. Small, minimalist, and incredibly focused on the quality of the brew. No frills, just exceptional coffee. It's a true coffee lover's spot.
#     *   **Location:** 1st Arrondissement (near Palais Royal)
#     *   **Must-try:** Simple espresso or a pour-over to appreciate the beans.
#
# 3.  **Ten Belles:**
#     *   **Why it's great:** Another early leader in Parisian specialty coffee. They have a fantastic vibe, excellent pastries, and consistently great coffee. They also roast their own beans (often used in their other locations).
#     *   **Locations:** Canal Saint-Martin (original), and a larger bakery/cafe near Gare du Nord (Ten Belles Bread).
#     *   **Must-try:** Latte with one of their delicious pastries.
#
# 4.  **Coutume Café:**
#     *   **Why it's great:** They've expanded to multiple locations, all offering consistent, high-quality coffee. They roast their own beans and have a great selection of filter and espresso options. Often a good spot for a light breakfast or lunch too.
#     *   **Locations:** Multiple across Paris (e.g., Rue de Babylone, Rue de Sèvres).
#     *   **Must-try:** Their flat white or a cold brew.
#
# 5.  **L'Arbre à Café:**
#     *   **Why it's great:** Highly revered for its extremely high-quality, ethically sourced beans, often supplied to Michelin-starred restaurants. They have a few very elegant, quiet coffee shops. If you're looking for a refined coffee experience, this is it.
#     *   **Locations:** Saint-Germain-des-Prés, plus a few others.
#     *   **Must-try:** Ask for their current exceptional single origin.
#
# 6.  **Fragments:**
#     *   **Why it's great:** Located in the charming Marais district, Fragments offers great coffee in a rustic, relaxed setting. Known for their excellent brunch as well, but the coffee stands strong on its own.
#     *   **Location:** Le Marais (3rd Arrondissement).
#     *   **Must-try:** Espresso-based drink and enjoy the ambiance.
#
# ---
#
# ## Best Coffee Shops in Lyon
#
# Outside of Paris, Lyon has a thriving specialty coffee scene.
#
# 1.  **Mokxa:**
#     *   **Why it's great:** Mokxa is Lyon's premier specialty coffee roaster and cafe. They were instrumental in bringing quality coffee to Lyon. Their shop is fantastic, offering a range of expertly prepared coffees.
#     *   **Locations:** Multiple in Lyon (e.g., Rue de la Platière).
#     *   **Must-try:** Whatever their current featured single origin is for filter coffee.
#
# 2.  **Slake Coffee House:**
#     *   **Why it's great:** A popular spot in Lyon with a cozy atmosphere and a serious approach to coffee. They work with high-quality roasters and have skilled baristas. Great for a comfortable coffee break.
#     *   **Location:** Presqu'île (Lyon city center).
#     *   **Must-try:** A well-made cappuccino.
#
# ---
#
# ## General Tips for Finding Quality Coffee in France:
#
# *   **Look for Filter Coffee:** If a shop offers V60, Chemex, Aeropress, or any other filter brew method, it's a strong indicator they care about specialty coffee.
# *   **Check the Roaster:** Many excellent cafes display the roaster they use (e.g., Belleville, Mokxa, L'Arbre à Café, Coutume, or other European roasters like Square Mile, Five Elephant).
# *   **Barista Interaction:** Quality coffee shops often have baristas who are knowledgeable and happy to talk about their beans and brewing methods.
# *   **Minimalist Aesthetic:** While not always true, many top-tier coffee shops have a clean, minimalist design that puts the focus on the product.
#
# Enjoy your coffee journey in France! You're in for a treat once you find these gems.
# Gemini: Machine Learning (ML) is a subfield of Artificial Intelligence (AI) that focuses on enabling systems to **learn from data**, **identify patterns**, and **make decisions or predictions** with minimal human intervention, rather than being explicitly programmed for every possible scenario.
#
# Think of it like teaching a child: instead of giving them a strict rulebook for every situation, you show them many examples, and they gradually learn to generalize and make their own judgments.
#
# Here's a breakdown of the core ideas:
#
# 1.  **Learning from Data:** The fundamental principle is that machines "learn" by being exposed to large amounts of data. This data can include numbers, text, images, sounds, etc. The more relevant and diverse the data, the better the machine can learn.
#
# 2.  **Pattern Recognition:** ML algorithms are designed to find hidden patterns, correlations, and insights within this data that might be too complex or time-consuming for humans to discover manually.
#
# 3.  **Making Predictions/Decisions:** Once trained on data, the machine can then apply what it has learned to new, unseen data to make predictions, classifications, or informed decisions.
#
# 4.  **No Explicit Programming (for every rule):** Unlike traditional programming where a developer writes explicit instructions for every possible input and output, ML models are given data and an algorithm, and they figure out the rules themselves. You don't tell the computer "if X and Y, then Z"; you show it many examples where X and Y lead to Z, and it learns the relationship.
#
# ### How it Generally Works:
#
# 1.  **Data Collection:** Gathering relevant data.
# 2.  **Data Preparation:** Cleaning, organizing, and transforming data to make it suitable for a model.
# 3.  **Choosing a Model/Algorithm:** Selecting the right ML algorithm (e.g., neural network, decision tree, support vector machine) based on the problem.
# 4.  **Training:** Feeding the prepared data into the algorithm. The algorithm "learns" by adjusting its internal parameters to find the best patterns and relationships within the data.
# 5.  **Evaluation:** Testing the trained model on new, unseen data to see how well it performs and if it generalizes accurately.
# 6.  **Deployment & Monitoring:** Once satisfied, the model can be used in real-world applications and continuously monitored for performance.
#
# ### Main Types of Machine Learning:
#
# 1.  **Supervised Learning:** The most common type. The model learns from "labeled" data, meaning each piece of input data is paired with the correct output.
#     *   **Examples:** Spam detection (email labeled as "spam" or "not spam"), image recognition (pictures labeled as "cat" or "dog"), predicting housing prices (house features linked to actual prices).
#
# 2.  **Unsupervised Learning:** The model learns from "unlabeled" data, trying to find hidden structures, groupings, or patterns without any prior knowledge of what the output should be.
#     *   **Examples:** Customer segmentation (grouping customers by similar purchasing behavior), anomaly detection (finding unusual activities in network traffic), topic modeling (identifying themes in a collection of documents).
#
# 3.  **Reinforcement Learning:** The model (an "agent") learns by interacting with an environment. It receives "rewards" for desirable actions and "penalties" for undesirable ones, aiming to maximize its cumulative reward over time through trial and error.
#     *   **Examples:** Game AI (AlphaGo, self-playing video games), robotics (learning to walk or grasp objects), controlling autonomous vehicles.
#
# ### Why is it Important?
#
# Machine Learning is at the core of many technologies we use daily and is transforming industries because it allows us to:
#
# *   **Automate Complex Tasks:** Tasks that are too intricate for traditional programming.
# *   **Discover Hidden Insights:** Find patterns in massive datasets that human analysts might miss.
# *   **Personalize Experiences:** Recommendation engines (Netflix, Amazon), personalized news feeds.
# *   **Adapt and Improve:** Models can continuously learn and get better as they encounter more data.
#
# **In essence, Machine Learning is about building intelligent systems that can learn and adapt, making them incredibly powerful tools for solving complex problems and driving innovation across virtually every industry.**
# Gemini: Ah, the quest for the perfect biryani in London! It's a noble pursuit, and "best" is always subjective when it comes to such a beloved and regionally varied dish. However, I can give you some highly acclaimed options that consistently get rave reviews for their biryani.
#
# The style of biryani (Hyderabadi, Lucknowi, Karachi, Bengali, etc.) also plays a huge role in what someone considers "best."
#
# Here are my top recommendations for biryani in London, catering to different preferences:
#
# 1.  **Dum Biryani House (Soho)**
#     *   **Style:** Primarily Hyderabadi Dum Biryani.
#     *   **Why it's great:** This place is *dedicated* to biryani, and they do it exceptionally well. Their lamb biryani is a standout, cooked in the traditional "dum" style, meaning it's slow-cooked in a sealed pot, allowing the flavors to deeply infuse. The rice is aromatic, the meat tender, and the spices perfectly balanced. It's a bit more upscale than some, but worth it for a truly authentic biryani experience.
#
# 2.  **Karachi Cuisine (Norbury / Tooting)**
#     *   **Style:** Authentic Pakistani/Karachi style.
#     *   **Why it's great:** If you're looking for a truly authentic, no-frills, incredibly flavorful Pakistani biryani, Karachi Cuisine is a must-visit. Their biryanis (especially the lamb and chicken) are legendary among the community. Portions are generous, the rice is perfectly cooked, and the spices have a wonderful depth and kick. It's a bustling spot, very popular, and offers great value.
#
# 3.  **Paradise (Willesden Green / various locations)**
#     *   **Style:** Pakistani (often with Hyderabadi influences).
#     *   **Why it's great:** Another strong contender for excellent Pakistani-style biryani. Many rave about their lamb biryani, noting its fragrant rice, tender meat, and well-spiced gravy. It's a local favourite for many who seek genuine flavours outside the central London fine-dining scene.
#
# 4.  **Dishoom (Various locations - particularly Shoreditch, Covent Garden, King's Cross)**
#     *   **Style:** Bombay-inspired, but their biryani is well-executed.
#     *   **Why it's great:** While not a biryani specialist, Dishoom's biryanis (chicken and lamb) are consistently good, accessible, and a popular choice. They do a solid job, with fragrant rice and tender meat, and they're perfect if you want a reliable biryani in a lively, well-designed setting. Their *Berry Pulao* is also a unique and delicious rice dish worth trying.
#
# 5.  **Mirch Masala (Southall / Tooting / Wembley)**
#     *   **Style:** Pakistani.
#     *   **Why it's great:** Similar to Karachi Cuisine, Mirch Masala is a very popular spot for authentic Pakistani food, and their biryani is often highlighted as a must-try. Expect generous portions, robust flavours, and a truly local experience.
#
# **Tips for choosing:**
#
# *   **What style do you prefer?** If you like the deep, aromatic, slightly less spicy Hyderabadi style, Dum Biryani House is fantastic. If you prefer a more robust, spicier Pakistani/Karachi flavour, then Karachi Cuisine or Mirch Masala are excellent.
# *   **Location:** London is big! Consider where you are.
# *   **Ambiance:** Do you want a lively, casual spot (Karachi Cuisine, Mirch Masala, Tayyabs) or something a bit more refined (Dum Biryani House, Dishoom)?
# *   **Reviews:** Always check recent reviews for consistency!
#
# My personal vote for a dedicated, outstanding biryani experience would be **Dum Biryani House** for its mastery of the Hyderabadi style, and **Karachi Cuisine** for an authentic, flavour-packed Pakistani biryani.
#
# Enjoy your biryani quest!
# Gemini: Chennai's coffee scene has grown significantly, especially in the specialty/third-wave segment. When looking for the "best quality," you're generally seeking places that focus on high-grade beans (single origin, ethically sourced), expert roasting, meticulous brewing methods, and skilled baristas.
#
# Here are some of the top recommendations for the best quality coffeeshops in Chennai:
#
# 1.  **Blue Tokai Coffee Roasters:**
#     *   **Why it's top-tier:** Blue Tokai is one of India's leading specialty coffee roasters. They roast their own beans, offer a wide variety of single origins and blends, and have highly trained baristas. You can expect excellent espresso-based drinks, as well as pour-overs, AeroPress, and French press options. Their cafes often have a relaxed, industrial-chic vibe.
#     *   **Locations:** Multiple across Chennai (e.g., Alwarpet, Nungambakkam, Kotturpuram).
#
# 2.  **Third Wave Coffee Roasters:**
#     *   **Why it's top-tier:** Another prominent name in India's specialty coffee scene, Third Wave focuses on sourcing high-quality beans and providing a premium coffee experience. They offer a good range of brews, including pour-overs and various espresso options, along with a solid food menu.
#     *   **Locations:** Multiple across Chennai (e.g., Alwarpet, Anna Nagar, Besant Nagar).
#
# 3.  **Curry Up Coffee:**
#     *   **Why it's great:** This is a fantastic local gem and one of Chennai's pioneers in specialty coffee. They are passionate about their beans and brewing. You'll often find unique and interesting single-origin options here, prepared with care. It has a more intimate and dedicated coffee-lover feel.
#     *   **Location:** T Nagar (Nageswara Rao Road).
#
# 4.  **The Brew Room (Savera Hotel):**
#     *   **Why it's great:** While part of a hotel, The Brew Room is known for its elegant ambiance and consistently good coffee. They pay attention to their sourcing and preparation, offering a refined coffee experience alongside excellent pastries and light bites. It's a great spot for a more upscale and relaxed coffee session.
#     *   **Location:** Dr. Radhakrishnan Salai (Mylapore).
#
# 5.  **Coffee? (Besant Nagar):**
#     *   **Why it's great:** A quaint and popular spot in Besant Nagar, this cafe often surprises with its quality. They focus on delivering good coffee consistently in a cozy setting. While perhaps not as experimental as a dedicated roaster, their standard offerings are well-executed.
#     *   **Location:** Besant Nagar.
#
# **Tips for choosing and enjoying:**
#
# *   **Ask the Barista:** Don't hesitate to ask about their current single-origin offerings, different brewing methods, and recommended pairing.
# *   **Try a Pour-Over:** If you're looking for the purest expression of a coffee bean's flavor, a pour-over (V60, Chemex) is a great choice.
# *   **Explore Different Beans:** Many of these places offer a rotating selection of beans from various Indian estates or even international origins.
# *   **Consider the Ambiance:** Each place has a slightly different vibe, so pick one that suits your mood – from a bustling co-working friendly space to a quiet corner for reflection.
#
# You can't go wrong with any of these choices if you're looking for genuinely high-quality coffee in Chennai!
